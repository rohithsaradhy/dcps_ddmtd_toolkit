# %%
from tools.base import *
from tools.ddmtd import *
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from time import sleep 
from copy import deepcopy
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib
matplotlib.style.available
matplotlib.style.use(['seaborn-darkgrid','science'])
# plt.rcParams['figure.figsize'] = [4, 3]
plt.rcParams['figure.dpi'] = 300

# %%
#Generate column names
NUM_WORDS = 32
column_names = []
for i in range(1,NUM_WORDS+1):
    column_names.append(f"edge{i}")
    column_names.append(f"ddmtd{i}")
    
# pd.set_option('max_columns', None)
# pd.set_option('max_rows', 100)

# %%
# freq=160
# board_num = 4
# server="board3_trenz"
# rpi_server="board3_pi"
# !../RPi/config_pll.sh {rpi_server} ../RPi/ 2021_10_05_Si5344H/OCXO/Si5344H-RevD-Registers_{freq}M.h 2021_10_05_Si5344H/PLL/Si5344H-RevD-Registers_{freq}M_100K.h {board_num}

# %%
server="board2_trenz"
rpi_server="board2_pi"

# %%
# aq_iter=100
# !../acq_software/run_atTrenz.sh ../acq_software/ {aq_iter} {server}

# %%
0b11
# Out:
# 3

# %%
# def get_data(step,channel =5,folder="",aq_iter = 100):
#     data_folder = f"data_files/{folder}/c{channel}_data_step_{str(step).zfill(3)}/"
#     !mkdir -p {data_folder}
#     !../acq_software/run_atPi.sh ../acq_software/ {step} {channel} {rpi_server}
#     !../acq_software/run_atTrenz.sh ../acq_software/ {aq_iter} {server}
#     !sshpass -p "root" rsync -aP {server}:data_acq/data_files/ddmtd1.txt ./{data_folder}/ddmtd1.txt
#     !sshpass -p "root" rsync -aP {server}:data_acq/data_files/ddmtd2.txt ./{data_folder}/ddmtd2.txt
#     !sshpass -p "root" rsync -aP {server}:data_acq/data_files/ddmtd3.txt ./{data_folder}/ddmtd3.txt


def get_data(fine_delay,coarse_delay ,channel =5,folder="",aq_iter = 100):
    data_folder = f"data_files/{folder}/c{channel}_fstep_{str(fine_delay).zfill(3)}_cstep_{str(coarse_delay).zfill(3)}"
    # !mkdir -p {data_folder}
    # !../acq_software/run_atPi.sh ../acq_software/ {fine_delay} {coarse_delay} {channel} {rpi_server}
    # !../acq_software/run_atTrenz.sh ../acq_software/ {aq_iter} {server}
    # !rsync -aP {server}:data_acq/data_files/ddmtd1.txt ./{data_folder}/ddmtd1.txt
    # !rsync -aP {server}:data_acq/data_files/ddmtd2.txt ./{data_folder}/ddmtd2.txt
    # !rsync -aP {server}:data_acq/data_files/ddmtd3.txt ./{data_folder}/ddmtd3.txt
        
        
def debug_spi(fine_delay,coarse_delay ,channel =5,folder="",aq_iter = 100):
    data_folder = f"data_files/{folder}/c{channel}_fstep_{str(fine_delay).zfill(3)}_cstep_{str(coarse_delay).zfill(3)}"
    # !mkdir -p {data_folder}
    # !../acq_software/run_atPi.sh ../acq_software/ {fine_delay} {coarse_delay} {channel} {rpi_server}
#     !../acq_software/run_atTrenz.sh ../acq_software/ {aq_iter} {server}
#     !rsync -aP {server}:data_acq/data_files/ddmtd1.txt ./{data_folder}/ddmtd1.txt
#     !rsync -aP {server}:data_acq/data_files/ddmtd2.txt ./{data_folder}/ddmtd2.txt
#     !rsync -aP {server}:data_acq/data_files/ddmtd3.txt ./{data_folder}/ddmtd3.txt
        
        
        

def plot_data(fine_delay=0,coarse_delay=0,channel =10,folder="",freq=160*10**6,data_stream = (1,3),draw=False):   
    df = data2df(fine_delay
             ,coarse_delay
             ,channel=channel
             ,folder=folder
             ,freq = freq
             ,data_stream = data_stream
            )
#     popt,p_err = df.drawTIE(save_name='',bns=None,fit=True, sep="TIE_FALL")
    popt,p_err = df.drawTIE(save_name='',bns=None,fit=True, sep="",draw=draw)
    # popt,p_err = df.drawTIE(save_name='',bns=None,fit=True, sep="TIE_FALL",draw=draw)

    


    return (popt[1]*1000,p_err[1]*1000)
    
    

def plot_tie(tie):
    f,ax = plt.subplots(figsize=(8,6))
    
    ax.errorbar(tie[0],tie[1],yerr=tie[2],fmt='o',
#                         color='red',
                        capsize=5,
                        ecolor='black'
                        ,label=f'ODD'
                       )
#     ax.errorbar(tie[0],tie[3],yerr=tie[4],fmt='o',
# #                         color='red',
#                         capsize=5,
#                         ecolor='black'
#                         ,label=f'EVEN'
#                        )
    plt.xlabel("Delay cell index", fontsize=15)
    plt.ylabel("TIE [ps] staggered", fontsize=15)
    plt.legend(loc="upper right")
    plt.gca().grid()
    
def data2df(fine_delay=0,coarse_delay=0,channel =5,folder="",freq=160*10**6, data_stream = (1,3)):
    data_folder = f"data_files/{folder}/c{channel}_fstep_{str(fine_delay).zfill(3)}_cstep_{str(coarse_delay).zfill(3)}"
    dv1= pd.read_csv(f"{data_folder}/ddmtd1.txt",sep=",",header=0 ,skiprows=0,names=column_names[0:16])
    dv2= pd.read_csv(f"{data_folder}/ddmtd2.txt",sep=",",header=0 ,skiprows=0,names=column_names[16:32])
    dv3= pd.read_csv(f"{data_folder}/ddmtd3.txt",sep=",",header=0 ,skiprows=0,names=column_names[32:48])
    dv = pd.concat((dv1,dv2,dv3),axis=1)  
#     dv = dv1
#     df = deepcopy(dv[(dv.T != 0).any()])
#     df = df.reset_index(drop=1)
    df = deepcopy(dv)
#     return df 
#     df = df[df.ddmt d3!=2147483647].reset_index(drop=1).drop([0,1,2])    
#     df.iloc[0,:]=0
#     return df
    data = ddmtd(deepcopy(df),q=1,channel=data_stream)
    data.N=100000
    data.INPUT_FREQ = freq
    data.Recalc()
    return data 

def config_dcps(fine_delay,course_delay,channel,rpi_server):
    # !../acq_software/run_atPi.sh ../acq_software/ {fine_delay} {coarse_delay} {channel} {rpi_server}


    
def get_data_debug(step,channel =5,folder="",aq_iter = 100,sleep_time=20000):
    data_folder = f"data_files/{folder}/c{channel}_data_step_{str(step).zfill(3)}/"
    # !mkdir -p {data_folder}
    # !../acq_software/run_atTrenz.sh ../acq_software/ {aq_iter} {server} {sleep_time}
    # !sshpass -p "root" rsync -aP {server}:data_acq/data_files/ddmtd1.txt ./{data_folder}/ddmtd1.txt
    # !sshpass -p "root" rsync -aP {server}:data_acq/data_files/ddmtd2.txt ./{data_folder}/ddmtd2.txt
    # !sshpass -p "root" rsync -aP {server}:data_acq/data_files/ddmtd3.txt ./{data_folder}/ddmtd3.txt
        
        
def copy_data(step,channel =5,folder="",aq_iter = 100,sleep_time=20000):
    data_folder = f"data_files/{folder}/c{channel}_data_step_{str(step).zfill(3)}/"
    # !mkdir -p {data_folder}
    # !sshpass -p "root" rsync -aP {server}:data_acq/data_files/ddmtd1.txt ./{data_folder}/ddmtd1.txt
    # !sshpass -p "root" rsync -aP {server}:data_acq/data_files/ddmtd2.txt ./{data_folder}/ddmtd2.txt
    # !sshpass -p "root" rsync -aP {server}:data_acq/data_files/ddmtd3.txt ./{data_folder}/ddmtd3.txt

# %%
freq=160

# %%
# board_num = 4

# for i in range(100):
# !../RPi/config_pll.sh {rpi_server} ../RPi/ 2021_10_05_Si5344/OCXO/Si5344-RevD-Registers_{freq}M.h 2021_10_05_Si5344/PLL/Si5344-RevD-Registers_{freq}M_100K.h {board_num}

board_num=3
# !../RPi/config_pll.sh {rpi_server} ../RPi/ 2021_10_05_Si5344H/OCXO/Si5344H-RevD-Registers_{freq}M.h 2021_10_05_Si5344H/PLL/Si5344H-RevD-Registers_{freq}M_100K.h {board_num}
# Out:
# Board Number 3 chosen; make sure this is the correct board
#
# Wi-Fi is currently blocked by rfkill.
# Use raspi-config to set the country before use.
#
# We are in dir::/home/pi/Flash_Firmware
# Done Compiling PLLs
#
# TBUFF[2] = 60
#
# RBUFF[0] = 0
# RBUFF[1] = 0
# RBUFF[2] = 60
# address = 0x0514, value = 0x01 ; Value returned = 0x00
# address = 0x001c, value = 0x01 ; Value returned = 0x00
#
# TBUFF[2] = 47
#
# RBUFF[0] = 0
# RBUFF[1] = 0
# RBUFF[2] = 47
# address = 0x0514, value = 0x01 ; Value returned = 0x00
# address = 0x001c, value = 0x01 ; Value returned = 0x00

# %%
# def config_dcps(fine_delay,course_delay,channel,rpi_server):
#     !../acq_software/run_atPi.sh ../acq_software/ {fine_delay} {coarse_delay} {channel}

# %%
# folder_name = f"2022_04_14_{freq}MHz"

# %%
# for i in range(100):
#     debug_spi(0,16,channel=4,folder=folder_name,aq_iter=100)
#     sleep(.1)
# #     debug_spi(0,16,channel=5,folder=folder_name,aq_iter=100)
# #     sleep(.1)

# %%
# for i in range(6):

#     debug_spi(0,16,channel=i,folder=folder_name,aq_iter=100)
#     sleep(1)

# %%
# Channel 0: CS Works (CS5)
# Channel 1: CS Works (CS6)
# Channel 2: No CS
# Channel 3: No CS
# Channel 4: Has CS (CS5)
# Channel 5: Has CS (CS6)

# %%
folder_name = f"2023_05_11_{freq}MHz"
channel = 1
f_step = 0
c_step = 0
get_data(f_step,c_step,channel=channel,folder=folder_name,aq_iter=100)
# f_step1 = 0
# c_step1 = 30
# get_data(f_step1,c_step1,channel=channel,folder=folder_name,aq_iter=100)
# Out:
# Wi-Fi is currently blocked by rfkill.
# Use raspi-config to set the country before use.
#
# Done Compiling RPI DCPS
# 0 fine delay step selected
# 0 coarse delay step selected
# 1 channel selected
# Selected Fiber 1 edited
# 1 bit is  0
# 2 bit is  0
# 3 bit is  0
# 4 bit is  0
# 5 bit is  0
#
# 32 bits::: MSB: 0000 0000 0000 1111 1000 0011 1110 0000 :LSB
#
# 32 bits::: MSB: 0000 0000 0000 0000 0000 0000 0000 0000 :LSB
#
# 32 bits::: MSB: 1111 1111 1111 1111 1111 1100 0000 0000 :LSB
#
# 32 bits::: MSB: 1111 1111 1111 1111 1111 1111 1111 1111 :LSB
#
#
# cmd_buf Forward
# Running & Compiling Section
# Loading Firmware: 2021_10_11_firmware_v2.4.bit.bin
# Running get_data_bram
# Firmware Version: 2.4
#  receiving file list ...
# 1 file to consider
# ddmtd1.txt
#      7842934 100%   11.16MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 16850 bytes  received 7814193 bytes  5220695.33 bytes/sec
# total size is 7842934  speedup is 1.00
# receiving file list ...
# 1 file to consider
# ddmtd2.txt
#      8502504 100%   10.29MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 17558 bytes  received 8475603 bytes  5662107.33 bytes/sec
# total size is 8502504  speedup is 1.00
# receiving file list ...
# 1 file to consider
# ddmtd3.txt
#      8521738 100%   10.47MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 17600 bytes  received 8491933 bytes  17019066.00 bytes/sec
# total size is 8521738  speedup is 1.00

# %%
print(f"{'channel':^20}|{'deltaF':^20}|{'deltaC':^20}|{'tie':^20}|{'tie1':^20}|{'np.abs(tie1-tie)':^20} ")

for scan_ch in [2,6,7,10,11]:
        print(scan_ch)
        data_stream =  (1,scan_ch)
        tie,tie_err = plot_data(f_step
                ,c_step
                ,channel=channel
                ,folder=folder_name
                ,freq = freq*10**6
                ,data_stream = data_stream
                ,draw=False
                )

        tie1,tie_err1 = plot_data(f_step1
                ,c_step1
                ,channel=channel
                ,folder=folder_name
                ,freq = freq*10**6
                ,data_stream = data_stream
                ,draw=False
                )

        print(f"{scan_ch:^20}|{f_step1-f_step:^20}|{c_step1-c_step:^20}|{tie:^20.2f}|{tie1:^20.2f}|{np.abs(tie1-tie):^20.2f}")
# Out:
#       channel       |       deltaF       |       deltaC       |        tie         |        tie1        |  np.abs(tie1-tie)
# 2
#          2          |         0          |         30         |      4994.36       |      4994.19       |        0.17
# 6
#          6          |         0          |         30         |      5381.57       |      5381.78       |        0.21
# 7
#          7          |         0          |         30         |      2472.56       |      2472.55       |        0.02
# 10
#          10         |         0          |         30         |      5612.37       |      5612.65       |        0.28
# 11
#          11         |         0          |         30         |      2706.50       |      2706.47       |        0.03

# %%
#  Map of the data stream
data_stream=[
    (2,10), #0
    (2,6),  #1
    (3,2),  #2
    (2,3),  #3
    (2,7),  #4
    (2,11), #5
]

# %%
tie,tie_err = plot_data(f_step
        ,c_step
        ,channel=channel
        ,folder=folder_name
        ,freq = freq*10**6
        ,data_stream = (2,10)
        ,draw=True
        )

# %%
folder_name = f"2023_05_09_{freq}MHz"
channel = 0
for j in range(0,32,4):
    get_data(0,j,channel=channel,folder=folder_name,aq_iter=100)
# Out:
# Wi-Fi is currently blocked by rfkill.
# Use raspi-config to set the country before use.
#
# Done Compiling RPI DCPS
# 0 fine delay step selected
# 0 coarse delay step selected
# 0 channel selected
# Selected Fiber 0 edited
# 1 bit is  0
# 2 bit is  0
# 3 bit is  0
# 4 bit is  0
# 5 bit is  0
#
# 32 bits::: MSB: 0000 0000 0000 1111 1000 0011 1110 0000 :LSB
#
# 32 bits::: MSB: 0000 0000 0000 0000 0000 0000 0000 0000 :LSB
#
# 32 bits::: MSB: 1111 1111 1111 1111 1111 1100 0000 0000 :LSB
#
# 32 bits::: MSB: 1111 1111 1111 1111 1111 1111 1111 1111 :LSB
#
#
# cmd_buf Forward
# Copying firmware: 2021_10_11_firmware_v2.4.bit.bin
# Copying loading script: do_load.sh
# Copying Data_acq Folder
# building file list ... done
# data_acq/data_files/
#
# sent 523 bytes  received 26 bytes  1098.00 bytes/sec
# total size is 47279  speedup is 86.12
# Running & Compiling Section
# Loading Firmware: 2021_10_11_firmware_v2.4.bit.bin
# Hello
# Running get_data_bram
# Firmware Version: 2.4
#  receiving file list ...
# 1 file to consider
# ddmtd1.txt
#      7843289 100%   10.49MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 7845312 bytes  5230233.33 bytes/sec
# total size is 7843289  speedup is 1.00
# receiving file list ...
# 1 file to consider
# ddmtd2.txt
#      8502203 100%   10.38MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 8504386 bytes  5669616.00 bytes/sec
# total size is 8502203  speedup is 1.00
# receiving file list ...
# 1 file to consider
# ddmtd3.txt
#      8521738 100%   10.62MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 8523929 bytes  5682644.67 bytes/sec
# total size is 8521738  speedup is 1.00
#
# Wi-Fi is currently blocked by rfkill.
# Use raspi-config to set the country before use.
#
# Done Compiling RPI DCPS
# 0 fine delay step selected
# 4 coarse delay step selected
# 0 channel selected
# Selected Fiber 0 edited
# 1 bit is  0
# 2 bit is  0
# 3 bit is  1
# 4 bit is  0
# 5 bit is  0
#
# 32 bits::: MSB: 0000 0000 0000 1101 1001 0011 0110 0100 :LSB
#
# 32 bits::: MSB: 0000 0000 0000 0000 0000 0000 0000 0000 :LSB
#
# 32 bits::: MSB: 1111 1111 1111 1111 1111 1100 0000 0000 :LSB
#
# 32 bits::: MSB: 1111 1111 1111 1111 1111 1111 1111 1111 :LSB
#
#
# cmd_buf Forward
# Copying firmware: 2021_10_11_firmware_v2.4.bit.bin
# Copying loading script: do_load.sh
# Copying Data_acq Folder
# building file list ... done
# data_acq/data_files/
#
# sent 523 bytes  received 26 bytes  1098.00 bytes/sec
# total size is 47279  speedup is 86.12
# Running & Compiling Section
# Loading Firmware: 2021_10_11_firmware_v2.4.bit.bin
# Hello
# Running get_data_bram
# Firmware Version: 2.4
#  receiving file list ...
# 1 file to consider
# ddmtd1.txt
#      7843264 100%   10.54MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 7845287 bytes  5230216.67 bytes/sec
# total size is 7843264  speedup is 1.00
# receiving file list ...
# 1 file to consider
# ddmtd2.txt
#      8502106 100%   10.12MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 8504289 bytes  5669551.33 bytes/sec
# total size is 8502106  speedup is 1.00
# receiving file list ...
# 1 file to consider
# ddmtd3.txt
#      8521738 100%   11.03MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 8523929 bytes  5682644.67 bytes/sec
# total size is 8521738  speedup is 1.00
#
# Wi-Fi is currently blocked by rfkill.
# Use raspi-config to set the country before use.
#
# Done Compiling RPI DCPS
# 0 fine delay step selected
# 8 coarse delay step selected
# 0 channel selected
# Selected Fiber 0 edited
# 1 bit is  0
# 2 bit is  0
# 3 bit is  0
# 4 bit is  1
# 5 bit is  0
#
# 32 bits::: MSB: 0000 0000 0000 1011 1010 0010 1110 1000 :LSB
#
# 32 bits::: MSB: 0000 0000 0000 0000 0000 0000 0000 0000 :LSB
#
# 32 bits::: MSB: 1111 1111 1111 1111 1111 1100 0000 0000 :LSB
#
# 32 bits::: MSB: 1111 1111 1111 1111 1111 1111 1111 1111 :LSB
#
#
# cmd_buf Forward
# Copying firmware: 2021_10_11_firmware_v2.4.bit.bin
# Copying loading script: do_load.sh
# Copying Data_acq Folder
# building file list ... done
# data_acq/data_files/
#
# sent 523 bytes  received 26 bytes  1098.00 bytes/sec
# total size is 47279  speedup is 86.12
# Running & Compiling Section
# Loading Firmware: 2021_10_11_firmware_v2.4.bit.bin
# Hello
# Running get_data_bram
# Firmware Version: 2.4
#  receiving file list ...
# 1 file to consider
# ddmtd1.txt
#      7843357 100%   11.13MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 7845380 bytes  5230278.67 bytes/sec
# total size is 7843357  speedup is 1.00
# receiving file list ...
# 1 file to consider
# ddmtd2.txt
#      8501959 100%   11.06MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 8504142 bytes  5669453.33 bytes/sec
# total size is 8501959  speedup is 1.00
# receiving file list ...
# 1 file to consider
# ddmtd3.txt
#      8521730 100%   11.00MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 8523921 bytes  5682639.33 bytes/sec
# total size is 8521730  speedup is 1.00
#
# Wi-Fi is currently blocked by rfkill.
# Use raspi-config to set the country before use.
#
# Done Compiling RPI DCPS
# 0 fine delay step selected
# 12 coarse delay step selected
# 0 channel selected
# Selected Fiber 0 edited
# 1 bit is  0
# 2 bit is  0
# 3 bit is  1
# 4 bit is  1
# 5 bit is  0
#
# 32 bits::: MSB: 0000 0000 0000 1001 1011 0010 0110 1100 :LSB
#
# 32 bits::: MSB: 0000 0000 0000 0000 0000 0000 0000 0000 :LSB
#
# 32 bits::: MSB: 1111 1111 1111 1111 1111 1100 0000 0000 :LSB
#
# 32 bits::: MSB: 1111 1111 1111 1111 1111 1111 1111 1111 :LSB
#
#
# cmd_buf Forward
# Copying firmware: 2021_10_11_firmware_v2.4.bit.bin
# Copying loading script: do_load.sh
# Copying Data_acq Folder
# building file list ... done
# data_acq/data_files/
#
# sent 523 bytes  received 26 bytes  1098.00 bytes/sec
# total size is 47279  speedup is 86.12
# Running & Compiling Section
# Loading Firmware: 2021_10_11_firmware_v2.4.bit.bin
# Hello
# Running get_data_bram
# Firmware Version: 2.4
#  receiving file list ...
# 1 file to consider
# ddmtd1.txt
#      7843391 100%   11.27MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 7845414 bytes  15690904.00 bytes/sec
# total size is 7843391  speedup is 1.00
# receiving file list ...
# 1 file to consider
# ddmtd2.txt
#      8502000 100%   10.41MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 8504183 bytes  17008442.00 bytes/sec
# total size is 8502000  speedup is 1.00
# receiving file list ...
# 1 file to consider
# ddmtd3.txt
#      8521730 100%   10.39MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 8523921 bytes  17047918.00 bytes/sec
# total size is 8521730  speedup is 1.00
#
# Wi-Fi is currently blocked by rfkill.
# Use raspi-config to set the country before use.
#
# Done Compiling RPI DCPS
# 0 fine delay step selected
# 16 coarse delay step selected
# 0 channel selected
# Selected Fiber 0 edited
# 1 bit is  0
# 2 bit is  0
# 3 bit is  0
# 4 bit is  0
# 5 bit is  1
#
# 32 bits::: MSB: 0000 0000 0000 0111 1100 0001 1111 0000 :LSB
#
# 32 bits::: MSB: 0000 0000 0000 0000 0000 0000 0000 0000 :LSB
#
# 32 bits::: MSB: 1111 1111 1111 1111 1111 1100 0000 0000 :LSB
#
# 32 bits::: MSB: 1111 1111 1111 1111 1111 1111 1111 1111 :LSB
#
#
# cmd_buf Forward
# Copying firmware: 2021_10_11_firmware_v2.4.bit.bin
# Copying loading script: do_load.sh
# Copying Data_acq Folder
# building file list ... done
# data_acq/data_files/
#
# sent 523 bytes  received 26 bytes  1098.00 bytes/sec
# total size is 47279  speedup is 86.12
# Running & Compiling Section
# Loading Firmware: 2021_10_11_firmware_v2.4.bit.bin
# Hello
# Running get_data_bram
# Firmware Version: 2.4
#  receiving file list ...
# 1 file to consider
# ddmtd1.txt
#      7843227 100%   10.54MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 7845250 bytes  5230192.00 bytes/sec
# total size is 7843227  speedup is 1.00
# receiving file list ...
# 1 file to consider
# ddmtd2.txt
#      8502081 100%   10.42MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 8504264 bytes  5669534.67 bytes/sec
# total size is 8502081  speedup is 1.00
# receiving file list ...
# 1 file to consider
# ddmtd3.txt
#      8521738 100%   11.12MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 8523929 bytes  5682644.67 bytes/sec
# total size is 8521738  speedup is 1.00
#
# Wi-Fi is currently blocked by rfkill.
# Use raspi-config to set the country before use.
#
# Done Compiling RPI DCPS
# 0 fine delay step selected
# 20 coarse delay step selected
# 0 channel selected
# Selected Fiber 0 edited
# 1 bit is  0
# 2 bit is  0
# 3 bit is  1
# 4 bit is  0
# 5 bit is  1
#
# 32 bits::: MSB: 0000 0000 0000 0101 1101 0001 0111 0100 :LSB
#
# 32 bits::: MSB: 0000 0000 0000 0000 0000 0000 0000 0000 :LSB
#
# 32 bits::: MSB: 1111 1111 1111 1111 1111 1100 0000 0000 :LSB
#
# 32 bits::: MSB: 1111 1111 1111 1111 1111 1111 1111 1111 :LSB
#
#
# cmd_buf Forward
# Copying firmware: 2021_10_11_firmware_v2.4.bit.bin
# Copying loading script: do_load.sh
# Copying Data_acq Folder
# building file list ... done
# data_acq/data_files/
#
# sent 523 bytes  received 26 bytes  1098.00 bytes/sec
# total size is 47279  speedup is 86.12
# Running & Compiling Section
# Loading Firmware: 2021_10_11_firmware_v2.4.bit.bin
# Hello
# Running get_data_bram
# Firmware Version: 2.4
#  receiving file list ...
# 1 file to consider
# ddmtd1.txt
#      7843266 100%   10.49MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 7845289 bytes  5230218.00 bytes/sec
# total size is 7843266  speedup is 1.00
# receiving file list ...
# 1 file to consider
# ddmtd2.txt
#      8502118 100%   10.49MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 8504301 bytes  5669559.33 bytes/sec
# total size is 8502118  speedup is 1.00
# receiving file list ...
# 1 file to consider
# ddmtd3.txt
#      8521738 100%   10.84MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 8523929 bytes  5682644.67 bytes/sec
# total size is 8521738  speedup is 1.00
#
# Wi-Fi is currently blocked by rfkill.
# Use raspi-config to set the country before use.
#
# Done Compiling RPI DCPS
# 0 fine delay step selected
# 24 coarse delay step selected
# 0 channel selected
# Selected Fiber 0 edited
# 1 bit is  0
# 2 bit is  0
# 3 bit is  0
# 4 bit is  1
# 5 bit is  1
#
# 32 bits::: MSB: 0000 0000 0000 0011 1110 0000 1111 1000 :LSB
#
# 32 bits::: MSB: 0000 0000 0000 0000 0000 0000 0000 0000 :LSB
#
# 32 bits::: MSB: 1111 1111 1111 1111 1111 1100 0000 0000 :LSB
#
# 32 bits::: MSB: 1111 1111 1111 1111 1111 1111 1111 1111 :LSB
#
#
# cmd_buf Forward
# Copying firmware: 2021_10_11_firmware_v2.4.bit.bin
# Copying loading script: do_load.sh
# Copying Data_acq Folder
# building file list ... done
# data_acq/data_files/
#
# sent 523 bytes  received 26 bytes  1098.00 bytes/sec
# total size is 47279  speedup is 86.12
# Running & Compiling Section
# Loading Firmware: 2021_10_11_firmware_v2.4.bit.bin
# Hello
# Running get_data_bram
# Firmware Version: 2.4
#  receiving file list ...
# 1 file to consider
# ddmtd1.txt
#      7843257 100%   10.55MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 7845280 bytes  5230212.00 bytes/sec
# total size is 7843257  speedup is 1.00
# receiving file list ...
# 1 file to consider
# ddmtd2.txt
#      8502071 100%   10.44MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 8504254 bytes  5669528.00 bytes/sec
# total size is 8502071  speedup is 1.00
# receiving file list ...
# 1 file to consider
# ddmtd3.txt
#      8521738 100%   10.42MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 8523929 bytes  5682644.67 bytes/sec
# total size is 8521738  speedup is 1.00
#
# Wi-Fi is currently blocked by rfkill.
# Use raspi-config to set the country before use.
#
# Done Compiling RPI DCPS
# 0 fine delay step selected
# 28 coarse delay step selected
# 0 channel selected
# Selected Fiber 0 edited
# 1 bit is  0
# 2 bit is  0
# 3 bit is  1
# 4 bit is  1
# 5 bit is  1
#
# 32 bits::: MSB: 0000 0000 0000 0001 1111 0000 0111 1100 :LSB
#
# 32 bits::: MSB: 0000 0000 0000 0000 0000 0000 0000 0000 :LSB
#
# 32 bits::: MSB: 1111 1111 1111 1111 1111 1100 0000 0000 :LSB
#
# 32 bits::: MSB: 1111 1111 1111 1111 1111 1111 1111 1111 :LSB
#
#
# cmd_buf Forward
# Copying firmware: 2021_10_11_firmware_v2.4.bit.bin
# Copying loading script: do_load.sh
# Copying Data_acq Folder
# building file list ... done
# data_acq/data_files/
#
# sent 523 bytes  received 26 bytes  1098.00 bytes/sec
# total size is 47279  speedup is 86.12
# Running & Compiling Section
# Loading Firmware: 2021_10_11_firmware_v2.4.bit.bin
# Hello
# Running get_data_bram
# Firmware Version: 2.4
#  receiving file list ...
# 1 file to consider
# ddmtd1.txt
#      7843235 100%   10.55MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 7845258 bytes  15690592.00 bytes/sec
# total size is 7843235  speedup is 1.00
# receiving file list ...
# 1 file to consider
# ddmtd2.txt
#      8502081 100%   10.46MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 8504264 bytes  17008604.00 bytes/sec
# total size is 8502081  speedup is 1.00
# receiving file list ...
# 1 file to consider
# ddmtd3.txt
#      8521714 100%   10.49MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 8523905 bytes  5682628.67 bytes/sec
# total size is 8521714  speedup is 1.00

# %%
# get_data(24,0,channel=channel,folder=folder_name,aq_iter=100)

# %%
# Out:
# 0

# %%
2,6,7,10

# %%
X  = []
Y  = []
Ye = []
f_step=0
for c_step in range(0,32,4):
    try:
        tie,tie_err = plot_data(f_step
             ,c_step
             ,channel=channel
             ,folder=folder_name
             ,freq = freq*10**6
             ,data_stream = (1,6)
             ,draw=False
                )
        X.append(c_step)
        Y.append(tie)
        Ye.append(tie_err)
    except:
        print(f"{f_step} lost")


x = np.asarray(X)
y = np.abs(np.asarray(Y) - Y[0])
y_err = np.asarray(Ye)
f,ax = plt.subplots()

popt,pcov = np.polyfit(x,y,1,cov=True)
p_e = np.sqrt(np.diag(pcov))

ax.scatter(x,y)
ax.plot(x,popt[0]*x+popt[1],color="r",linestyle='--',label=f"Channel 0 \n{popt[0]:4.3}+/- {p_e[0]:4.2} [ps/step]")
ax.set_ylabel("Delay [ps]")
ax.set_xlabel("Fine Step")
ax.legend(loc="upper left",fontsize=10)

# %%
# channel = 0
# get_data(0,0,channel=channel,folder=folder_name,aq_iter=100)

# %%
folder_name = f"2022_05_01_{freq}MHz"
channel = 0
for i in range(0,32):
    get_data(0,i,channel=channel,folder=folder_name,aq_iter=100)
# Out:
# SSH is enabled and the default password for the 'pi' user has not been changed.
# This is a security risk - please login as the 'pi' user and type 'passwd' to set a new password.
#
#
# Wi-Fi is currently blocked by rfkill.
# Use raspi-config to set the country before use.
#
# Done Compiling RPI DCPS
# 0 fine delay step selected
# 0 coarse delay step selected
# 0 channel selected
# Selected Fiber 0 edited
# 1 bit is  0
# 2 bit is  0
# 3 bit is  0
# 4 bit is  0
# 5 bit is  0
#
# 32 bits::: MSB: 0000 0000 0000 1111 1000 0011 1110 0000 :LSB
#
# 32 bits::: MSB: 0000 0000 0000 0000 0000 0000 0000 0000 :LSB
#
# 32 bits::: MSB: 1111 1111 1111 1111 1111 1100 0000 0000 :LSB
#
# 32 bits::: MSB: 1111 1111 1111 1111 1111 1111 1111 1111 :LSB
#
#
# cmd_buf Forward
# Running & Compiling Section
# Loading Firmware: 2021_10_11_firmware_v2.4.bit.bin
# Running get_data_bram
# Firmware Version: 2.4
#  receiving file list ...
# 1 file to consider
# ddmtd1.txt
#      
speedup is 1.00
# receiving file list ...
# 1 file to consider
# ddmtd3.txt
#      8513730 100%  249.54kB/s    0:00:33 (xfer#1, to-check=0/1)
#
# sent 38 bytes  received 8515913 bytes  239885.94 bytes/sec
# total size is 8513730  speedup is 1.00

# %%
# tie,tie_err = plot_data(0
#                  ,1
#                  ,channel=channel
#                  ,folder=folder_name
#                  ,freq = freq*10**6
#                  ,data_stream = (11,7)
#                  ,draw=True
#                     )

# %%
folder_name = f"2022_05_01_{freq}MHz"

# %%
get_data(0,7,channel=channel,folder=folder_name,aq_iter=100)
# Out:
# SSH is enabled and the default password for the 'pi' user has not been changed.
# This is a security risk - please login as the 'pi' user and type 'passwd' to set a new password.
#
#
# Wi-Fi is currently blocked by rfkill.
# Use raspi-config to set the country before use.
#
# Done Compiling RPI DCPS
# 0 fine delay step selected
# 7 coarse delay step selected
# 0 channel selected
# Selected Fiber 0 edited
# 1 bit is  1
# 2 bit is  1
# 3 bit is  1
# 4 bit is  0
# 5 bit is  0
#
# 32 bits::: MSB: 0000 0000 0000 1100 0001 1111 0000 0111 :LSB
#
# 32 bits::: MSB: 0000 0000 0000 0000 0000 0000 0000 0000 :LSB
#
# 32 bits::: MSB: 1111 1111 1111 1111 1111 1100 0000 0000 :LSB
#
# 32 bits::: MSB: 1111 1111 1111 1111 1111 1111 1111 1111 :LSB
#
#
# cmd_buf Forward
# Running & Compiling Section
# Loading Firmware: 2021_10_11_firmware_v2.4.bit.bin
# Running get_data_bram
# Firmware Version: 2.4
#  receiving file list ...
# 1 file to consider
# ddmtd1.txt
#      8516529 100%    6.07MB/s    0:00:01 (xfer#1, to-check=0/1)
#
# sent 17582 bytes  received 8518712 bytes  2438941.14 bytes/sec
# total size is 8516529  speedup is 1.00
# receiving file list ...
# 1 file to consider
# ddmtd2.txt
#      8507283 100%    9.51MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 17564 bytes  received 8509466 bytes  3410812.00 bytes/sec
# total size is 8507283  speedup is 1.00
# receiving file list ...
# 1 file to consider
# ddmtd3.txt
#      8513746 100%    9.31MB/s    0:00:00 (xfer#1, to-check=0/1)
#
# sent 17582 bytes  received 8483933 bytes  3400606.00 bytes/sec
# total size is 8513746  speedup is 1.00

# %%
X  = []
Y  = []
Ye = []
for c_step in range(0,32):
    try:
        tie,tie_err = plot_data(0
             ,c_step
             ,channel=channel
             ,folder=folder_name
             ,freq = freq*10**6
             ,data_stream = (2,10)
             ,draw=False
                )
        X.append(c_step)
        Y.append(tie)
        Ye.append(tie_err)
    except:
        print(f"{c_step} lost")
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
np.diff(Y)
# Out:
# array([ -7.7267093 ,  -8.83167242,  -7.53074352,  -8.55183338,
#         -6.8780786 ,  -7.85425593,  -6.98297616,   1.13585788,
#         -6.33651975,  -7.9883558 ,  -6.83757782,  -7.96385106,
#         -6.85095333,  -7.20972388,  -6.66586652, -24.46111827,
#         -6.83376574,  -6.349368  ,  -6.91027644,  -6.71048848,
#         -6.24058436,  -7.04688923,  -6.7022084 ,   1.79691944,
#         -6.98664928,  -6.23598387,  -6.68843732,  -5.40140044,
#         -6.56669385,  -6.60187565,  -6.27637123])

# %%
Y
# Out:
# [904.7647454232422,
#  897.0380361211053,
#  888.2063637005442,
#  880.6756201847509,
#  872.1237868079746,
#  865.2457082107961,
#  857.3914522781297,
#  850.4084761169171,
#  851.5443339952534,
#  845.2078142484758,
#  837.2194584488193,
#  830.3818806292871,
#  822.4180295691659,
#  815.5670762364256,
#  808.3573523558337,
#  801.6914858393993,
#  777.2303675656996,
#  770.3966018300357,
#  764.0472338324357,
#  757.1369573968423,
#  750.4264689131286,
#  744.1858845510075,
#  737.1389953258588,
#  730.4367869300595,
#  732.2337063749382,
#  725.2470570971184,
#  719.0110732320036,
#  712.3226359163909,
#  706.9212354809795,
#  700.3545416315362,
#  693.7526659846221,
#  687.4762947574253]

# %%
x = np.asarray(X)
y = np.abs(np.asarray(Y) - Y[0])
y_err = np.asarray(Ye)
f,ax = plt.subplots()

popt,pcov = np.polyfit(x,y,1,cov=True)
p_e = np.sqrt(np.diag(pcov))

ax.scatter(x,y)
ax.plot(x,popt[0]*x+popt[1],color="r",linestyle='--',label=f"Channel 0 \n{popt[0]:4.3}+/- {p_e[0]:4.2} [ps/step]")
ax.set_ylabel("Delay [ps]")
ax.set_xlabel("Coarse Step")
ax.legend(loc="upper left",fontsize=10)

# %%
X  = []
Y  = []
Ye = []
for c_step in (0,1,2,4,8,16):
    try:
        tie,tie_err = plot_data(0
             ,c_step
             ,channel=channel
             ,folder=folder_name
             ,freq = freq*10**6
             ,data_stream = (2,10)
             ,draw=False
                )
        X.append(c_step)
        Y.append(tie)
        Ye.append(tie_err)
    except:
        print(f"{c_step} lost")
# Out:
# False
# False
# False
# False
# False
# False

# %%
np.abs(Y-Y[0])
# Out:
# array([  0.        ,   7.7267093 ,  16.55838172,  32.64095862,
#         53.22041143, 127.53437786])

# %%
data = {}
# folder_name = f"2022_04_12_{freq}MHz"
folder_name = f"2022_05_01_{freq}MHz"


for chan in (3,6,7,10,11):
    X  = []
    Y  = []
    Ye = []
    for c_step in (0,16):
        try:
            tie,tie_err = plot_data(0
                 ,c_step
                 ,channel=channel
                 ,folder=folder_name
                 ,freq = freq*10**6
                 ,data_stream = (2,chan)
                 ,draw=False
                    )
            X.append(c_step)
            Y.append(tie)
            Ye.append(tie_err)
        except:
            print(f"{c_step} lost")
    
    data[f"chan{chan}"] = np.asarray((X,Y,Ye))
#2,3
#6,7
#10,11
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
# !open .

# %%
for i in data.keys():
    X = data[i][0]*8
    Y = data[i][1]
#     print(Y)
    try:
        print(f"{i}\t{np.abs(np.diff(Y))[0]:5.5f}ps")
    except:
        print(f"{i}   lost")
# Out:
# chan3	6.14082ps
# chan6	0.04956ps
# chan7	0.51334ps
# chan10	0.23408ps
# chan11	128.04406ps

# %%
# # f,ax = plt.subplots(figsize=(8,6))
# for i in data.keys():
#     f,ax = plt.subplots(figsize=(8,6))

#     X = data[i][0]*8
#     Y = data[i][1]
# #     Ye = data[i][2]
#     ax.scatter(X,Y)
    
#     print(i)
#     ax.set_xlabel("ps")

# %%
# data["chan3"][1]

# %%
X = np.asarray(data).T[0]
Y = np.asarray(data).T[1]
Ye = np.asarray(data).T[2]



plt.scatter(X[X>20],Y[X>20])
plt.scatter(X,Y)

# %%
data = []
for c_step in range(0,32):
    try:
        tie,tie_err = plot_data(0
                 ,c_step
                 ,channel=10
                 ,folder=folder_name
                 ,freq = freq*10**6
                 ,data_stream = (2,6)
                 ,draw=False
                    )
        data.append((c_step,tie,tie_err))
    except:
        print(f"{c_step} lost")
#2,3
#6,7
#10,11
# Out:
# False
# False
# False
# 3 lost
# False
# False
# 6 lost
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
# folder_name = f"2022_04_14_{freq}MHz"
# for i in range(0,32):
#     get_data(i,0,channel=10,folder=folder_name,aq_iter=100)
